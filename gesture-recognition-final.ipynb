# %% [markdown]
# # Gesture Recognition
#
# In this project, you are going to build a 3D Conv model that will be able to predict the 5 gestures correctly. Please import the following libraries to get started.

# %%
import numpy as np
import os
import imageio
from skimage.io import imread
from skimage.transform import resize
from skimage.transform import resize, rescale
import datetime
import os
import tensorflow as tf
import matplotlib.pyplot as plt
np.random.seed(30)
import random as rn
rn.seed(30)
from keras import backend as K
tf.random.set_seed(30)

# %% [markdown]
# We set the random seed so that the results don't vary drastically.

# %% [markdown]
# In this block, you read the folder names for training and validation. You also set the `batch_size` here. Note that you set the batch size in such a way that you are able to use the GPU in full capacity. You keep increasing the batch size until the machine throws an error.

# %%
folder_path="/kaggle/input/project-data1/Project_data/"

# %%
train_doc = np.random.permutation(open(folder_path+'train.csv').readlines())
val_doc = np.random.permutation(open(folder_path+'val.csv').readlines())
num_classes = 5  #number of softmax classes

# %%
curr_dt_time = datetime.datetime.now()
train_path = folder_path+'train'
val_path = folder_path+'val'
num_train_sequences = len(train_doc)
print('# training sequences =', num_train_sequences)
num_val_sequences = len(val_doc)
print('# validation sequences =', num_val_sequences)
# Out:
# # training sequences = 663
# # validation sequences = 100

# %% [markdown]
# ## Common Utility

# %% [markdown]
# Common utility to plot loss and accuracy

# %%
def plot_loss_accuracy(history):
    # list all data in history
    print(history.history.keys())
    # summarize history for accuracy
    plt.plot(history.history['categorical_accuracy'])
    plt.plot(history.history['val_categorical_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    # summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

# %% [markdown]
# Common utility to calculate steps

# %%
def calculate_steps(num_train_sequences, num_val_sequences, batch_size):
    if (num_train_sequences%batch_size) == 0:
        steps_per_epoch = int(num_train_sequences/batch_size)
    else:
        steps_per_epoch = (num_train_sequences//batch_size) + 1

    if (num_val_sequences%batch_size) == 0:
        validation_steps = int(num_val_sequences/batch_size)
    else:
        validation_steps = (num_val_sequences//batch_size) + 1

    return steps_per_epoch,validation_steps

# %% [markdown]
# Common utility for callbacks

# %%
def model_callbacks(folder_name):
    model_name = str(folder_name) + '_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'
   
    if not os.path.exists(model_name):
        os.mkdir(model_name)

    filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

    checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', period=1)

    LR = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3, min_lr=0.0001, cooldown=1, verbose=1) # write the REducelronplateau code here

    return [checkpoint, LR]

# %% [markdown]
# ## Generator
# This is one of the most important part of the code. The overall structure of the generator has been given. In the generator, you are going to preprocess the images as you have images of 2 different dimensions as well as create a batch of video frames. You have to experiment with `img_idx`, `y`,`z` and normalization such that you get high accuracy.

# %%
from keras.preprocessing.image import ImageDataGenerator
#from keras.preprocessing.image import smart_resize

datagen = ImageDataGenerator(
    zoom_range=0.1,
    zca_whitening=True,
    width_shift_range=0.1,
    height_shift_range=0.1)

## Test code start
#360 by 360
image1 = imageio.imread(folder_path+"val/WIN_20180907_15_30_06_Pro_Right Swipe_new/WIN_20180907_15_30_06_Pro_00029.png")
#160 by 120
image2 = imageio.imread(folder_path+"val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00029.png")
#crop the images and resize them. Note that the images are of 2 different shape 
#and the conv3D will throw error if the inputs in a batch have different shapes                    
#print(image1.shape, image2.shape)
image1 = resize(image1, (120, 120), anti_aliasing=True)
image1 = datagen.random_transform(image1)                   
plt.imshow(image1)
plt.show()
image2 = resize(image2, (120, 120), anti_aliasing=True)
image2 = datagen.random_transform(image2)                 
plt.imshow(image2)
plt.show()
## Test code end

def generate(source_path, folder_list, batch_size, num_images=20, height=120, width=120, augment=False):
    #print( 'Source path = ', source_path, '; batch size =', batch_size)
    total_frames = 30

    while True:
        t = np.random.permutation(folder_list)
        num_batches = len(t)//batch_size # calculate the number of batches
        #img_idx = sorted(rn.sample(range(0, total_frames), num_images)) #create a list of image numbers you want to use for a particular video
        img_idx = np.round(np.linspace(0,total_frames-1,num_images)).astype(int) #create a list of image numbers you want to use for a particular video

        for batch in range(num_batches): # we iterate over the number of batches
            batch_data   = np.zeros((batch_size, num_images, height, width, 3)) # 3 is the number of channels RGB
            batch_labels = np.zeros((batch_size, 5)) # batch_labels is the one hot representation of the output           

            for folder in range(batch_size): # iterate over the batch_size
                imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) # read all the images in the folder
                for idx,item in enumerate(img_idx): #  Iterate over the frames/images of a folder to read them in
                    image = imageio.imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)

                    #crop the images and resize them. Note that the images are of 2 different shape 
                    #and the conv3D will throw error if the inputs in a batch have different shapes                    
                    h, w, c = image.shape
                    image = resize(image, (height, width), anti_aliasing=True)

                    # Randomly transform few images of few folders; note that folders are randomly shuffled in each epoch too
                    if augment:
                        if np.random.randn() > 0:
                            image = datagen.random_transform(image)                   

                    batch_data[folder,idx,:,:,0] = (image[...,0])/255 #normalise and feed in the image
                    batch_data[folder,idx,:,:,1] = (image[...,1])/255 #normalise and feed in the image
                    batch_data[folder,idx,:,:,2] = (image[...,2])/255 #normalise and feed in the image                  
                    
                batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1

            yield batch_data, batch_labels #you yield the batch_data and the batch_labels, remember what does yield do
        
        # write the code for the remaining data points which are left after full batches
        if (len(t)%batch_size):
            remaining_batch_size = len(t)%batch_size
            batch_data   = np.zeros((remaining_batch_size, num_images, height, width,3)) # 3 is the number of channels RGB
            batch_labels = np.zeros((remaining_batch_size,5)) # batch_labels is the one hot representation of the output           

            for folder in range(remaining_batch_size): # iterate over the batch_size
                imgs = os.listdir(source_path+'/'+ t[folder + (num_batches*batch_size)].split(';')[0]) # read all the images in the folder
                for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
                    image = imageio.imread(source_path+'/'+ t[folder + (num_batches*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                
                    #crop the images and resize them. Note that the images are of 2 different shape 
                    #and the conv3D will throw error if the inputs in a batch have different shapes
                    h, w, c = image.shape
                    image = resize(image, (height, width), anti_aliasing=True)                          
                    
                    # Randomly transform few images of few folders; note that folders are randomly shuffled in each epoch too
                    if augment:
                        if np.random.randn() > 0:
                            image = datagen.random_transform(image)                   

                    batch_data[folder,idx,:,:,0] = (image[...,0])/255 #normalise and feed in the image
                    batch_data[folder,idx,:,:,1] = (image[...,1])/255 #normalise and feed in the image
                    batch_data[folder,idx,:,:,2] = (image[...,2])/255 #normalise and feed in the image
                    #batch_data[folder,idx,:,:,0] = (image[...,0] - image[...,0].min())/(image[...,0].max() - image[...,0].min())#normalise and feed in the image
                    #batch_data[folder,idx,:,:,1] = (image[...,1] - image[...,1].min())/(image[...,1].max() - image[...,1].min())#normalise and feed in the image
                    #batch_data[folder,idx,:,:,2] = (image[...,2] - image[...,2].min())/(image[...,2].max() - image[...,2].min())#normalise and feed in the image
                    
                batch_labels[folder, int(t[folder + (num_batches*batch_size)].strip().split(';')[2])] = 1

            yield batch_data, batch_labels #you yield the batch_data and the batch_labels, remember what does yield do
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/preprocessing/image.py:1444: UserWarning: This ImageDataGenerator specifies `zca_whitening`, which overrides setting of `featurewise_center`.
#   warnings.warn(
# /tmp/ipykernel_32/490613900.py:12: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image1 = imageio.imread(folder_path+"val/WIN_20180907_15_30_06_Pro_Right Swipe_new/WIN_20180907_15_30_06_Pro_00029.png")
# /tmp/ipykernel_32/490613900.py:14: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image2 = imageio.imread(folder_path+"val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00029.png")

# %% [markdown]
# Note here that a video is represented above in the generator as (number of images, height, width, number of channels). Take this into consideration while creating the model architecture.

# %% [markdown]
# ## Model
# Here you make the model using different functionalities that Keras provides. Remember to use `Conv3D` and `MaxPooling3D` and not `Conv2D` and `Maxpooling2D` for a 3D convolution model. You would want to use `TimeDistributed` while building a Conv2D + RNN model. Also remember that the last layer is the softmax. Design the network in such a way that the model is able to give good accuracy on the least number of parameters so that it can fit in the memory of the webcam.

# %%
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, GRU, LSTM, Flatten, TimeDistributed, Flatten, BatchNormalization, Activation
from keras.layers.convolutional import Conv3D, MaxPooling3D, Conv2D, MaxPooling2D
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.regularizers import l2
from keras import optimizers

# %% [markdown]
# ### Convolutional 3D Models

# %%
# Common utility to create conv 3D models
def conv3D(conv_filters=(16, 32, 64, 128), dense_nodes=(256,128), dropout=0.25, num_images=20, height=120, width=120):

    model = Sequential()

    model.add(Conv3D(conv_filters[0], (3, 3, 3), padding='same', input_shape=(num_images, height, width, 3)))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling3D(pool_size=(2, 2, 2)))

    model.add(Conv3D(conv_filters[1], (3, 3, 3), padding='same'))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling3D(pool_size=(2, 2, 2)))
    
    model.add(Conv3D(conv_filters[2], (3, 3, 3), padding='same'))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling3D(pool_size=(2, 2, 2)))
    
    model.add(Conv3D(conv_filters[3], (3, 3, 3), padding='same'))    
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling3D(pool_size=(2, 2, 2)))
    
    model.add(Flatten())
    model.add(Dense(dense_nodes[0]))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(Dropout(dropout))

    model.add(Dense(dense_nodes[1]))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(Dropout(dropout))

    model.add(Dense(num_classes))
    model.add(Activation('softmax'))

    opt = optimizers.Adam() #write your optimizer
    model.compile(opt, loss='categorical_crossentropy', metrics=['categorical_accuracy'])    
    
    return model

# %% [markdown]
# ### Model 1

# %% [markdown]
# - 30 frames per video
# - (16, 32, 64, 128) filters
# - conv 3D layers
# - 256 dense layer
# - 128 dense layer
# - image size : 120 by 120

# %%
num_epochs = 25 # choose the number of epochs
print ('# epochs =', num_epochs)
batch_size = 10  #experiment with the batch size
print ('# batch size =', batch_size)
num_frames = 30
print ('# num_frames per video =', num_frames)
height = 120
width = 120

model = conv3D(num_images=num_frames)

print (model.summary())
# Out:
# # epochs = 25
# # batch size = 10
# # num_frames per video = 30
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_4 (Conv3D)           (None, 30, 120, 120, 16)  1312
#
#  activation_7 (Activation)   (None, 30, 120, 120, 16)  0
#
#  batch_normalization_6 (Batc  (None, 30, 120, 120, 16)  64
#  hNormalization)
#
#  max_pooling3d_4 (MaxPooling  (None, 15, 60, 60, 16)   0
#  3D)
#
#  conv3d_5 (Conv3D)           (None, 15, 60, 60, 32)    13856
#
#  activation_8 (Activation)   (None, 15, 60, 60, 32)    0
#
#  batch_normalization_7 (Batc  (None, 15, 60, 60, 32)   128
#  hNormalization)
#
#  max_pooling3d_5 (MaxPooling  (None, 7, 30, 30, 32)    0
#  3D)
#
#  conv3d_6 (Conv3D)           (None, 7, 30, 30, 64)     55360
#
#  activation_9 (Activation)   (None, 7, 30, 30, 64)     0
#
#  batch_normalization_8 (Batc  (None, 7, 30, 30, 64)    256
#  hNormalization)
#
#  max_pooling3d_6 (MaxPooling  (None, 3, 15, 15, 64)    0
#  3D)
#
#  conv3d_7 (Conv3D)           (None, 3, 15, 15, 128)    221312
#
#  activation_10 (Activation)  (None, 3, 15, 15, 128)    0
#
#  batch_normalization_9 (Batc  (None, 3, 15, 15, 128)   512
#  hNormalization)
#
#  max_pooling3d_7 (MaxPooling  (None, 1, 7, 7, 128)     0
#  3D)
#
#  flatten_1 (Flatten)         (None, 6272)              0
#
#  dense_3 (Dense)             (None, 256)               1605888
#
#  activation_11 (Activation)  (None, 256)               0
#
#  batch_normalization_10 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_4 (Dense)             (None, 128)               32896
#
#  activation_12 (Activation)  (None, 128)               0
#
#  batch_normalization_11 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_5 (Dense)             (None, 5)                 645
#
#  activation_13 (Activation)  (None, 5)                 0
#
# =================================================================
# Total params: 1,933,765
# Trainable params: 1,932,517
# Non-trainable params: 1,248
# _________________________________________________________________
# None

# %% [markdown]
# The `steps_per_epoch` and `validation_steps` are used by `fit_generator` to decide the number of next() calls it need to make.
# Let us now fit the model. This will start training the model and with the help of the checkpoints, you'll be able to save the model at the end of each epoch.

# %%
callbacks_list = model_callbacks("model_conv3D_1")

steps_per_epoch, validation_steps = calculate_steps(num_train_sequences, num_val_sequences, batch_size)

train_generator = generate(train_path, train_doc, batch_size, num_images=num_frames)

val_generator   = generate(val_path, val_doc, batch_size, num_images=num_frames)

# %%
history = model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                             callbacks=callbacks_list, validation_data=val_generator, 
                             validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# /tmp/ipykernel_32/2636822326.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1,
# /tmp/ipykernel_32/300689100.py:45: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
# Epoch 1/25
# 66/67 [============================>.] - ETA: 2s - loss: 1.5574 - categorical_accuracy: 0.4424
# /tmp/ipykernel_32/300689100.py:74: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread(source_path+'/'+ t[folder + (num_batches*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
# 67/67 [==============================] - ETA: 0s - loss: 1
25
# 67/67 [==============================] - ETA: 0s - loss: 0.1546 - categorical_accuracy: 0.9502
# Epoch 20: val_loss did not improve from 0.44404
# 67/67 [==============================] - 208s 3s/step - loss: 0.1546 - categorical_accuracy: 0.9502 - val_loss: 0.5738 - val_categorical_accuracy: 0.8200 - lr: 1.0000e-04
# Epoch 21/25
# 67/67 [==============================] - ETA: 0s - loss: 0.1587 - categorical_accuracy: 0.9502
# Epoch 21: val_loss did not improve from 0.44404
# 67/67 [==============================] - 210s 3s/step - loss: 0.1587 - categorical_accuracy: 0.9502 - val_loss: 0.5006 - val_categorical_accuracy: 0.8400 - lr: 1.0000e-04
# Epoch 22/25
# 67/67 [==============================] - ETA: 0s - loss: 0.1445 - categorical_accuracy: 0.9593
# Epoch 22: val_loss did not improve from 0.44404
# 67/67 [==============================] - 208s 3s/step - loss: 0.1445 - categorical_accuracy: 0.9593 - val_loss: 0.5358 - val_categorical_accuracy: 0.8400 - lr: 1.0000e-04
# Epoch 23/25
# 67/67 [==============================] - ETA: 0s - loss: 0.1316 - categorical_accuracy: 0.9593
# Epoch 23: val_loss did not improve from 0.44404
# 67/67 [==============================] - 210s 3s/step - loss: 0.1316 - categorical_accuracy: 0.9593 - val_loss: 0.5591 - val_categorical_accuracy: 0.8300 - lr: 1.0000e-04
# Epoch 24/25
# 67/67 [==============================] - ETA: 0s - loss: 0.1268 - categorical_accuracy: 0.9638
# Epoch 24: val_loss did not improve from 0.44404
# 67/67 [==============================] - 213s 3s/step - loss: 0.1268 - categorical_accuracy: 0.9638 - val_loss: 0.4913 - val_categorical_accuracy: 0.8500 - lr: 1.0000e-04
# Epoch 25/25
# 67/67 [==============================] - ETA: 0s - loss: 0.1442 - categorical_accuracy: 0.9593
# Epoch 25: val_loss did not improve from 0.44404
# 67/67 [==============================] - 210s 3s/step - loss: 0.1442 - categorical_accuracy: 0.9593 - val_loss: 0.4703 - val_categorical_accuracy: 0.8200 - lr: 1.0000e-04

# %%
plot_loss_accuracy(history)
# Out:
# dict_keys(['loss', 'categorical_accuracy', 'val_loss', 'val_categorical_accuracy', 'lr'])

# %% [markdown]
# ### Model 2

# %% [markdown]
# - 20 frames per video
# - (16, 32, 64, 128) filters
# - conv 3D layers
# - 256 dense layer
# - 128 dense layer
# - image size 120 by 120

# %%
num_epochs = 20 # choose the number of epochs
#print ('# epochs =', num_epochs)
batch_size = 10  #experiment with the batch size
print ('# batch size =', batch_size)
num_frames = 20
print ('# num_frames per video =', num_frames)
height = 120
width = 120

model = conv3D(num_images=num_frames)

print (model.summary())
# Out:
# # batch size = 10
# # num_frames per video = 20
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_8 (Conv3D)           (None, 20, 120, 120, 16)  1312
#
#  activation_14 (Activation)  (None, 20, 120, 120, 16)  0
#
#  batch_normalization_12 (Bat  (None, 20, 120, 120, 16)  64
#  chNormalization)
#
#  max_pooling3d_8 (MaxPooling  (None, 10, 60, 60, 16)   0
#  3D)
#
#  conv3d_9 (Conv3D)           (None, 10, 60, 60, 32)    13856
#
#  activation_15 (Activation)  (None, 10, 60, 60, 32)    0
#
#  batch_normalization_13 (Bat  (None, 10, 60, 60, 32)   128
#  chNormalization)
#
#  max_pooling3d_9 (MaxPooling  (None, 5, 30, 30, 32)    0
#  3D)
#
#  conv3d_10 (Conv3D)          (None, 5, 30, 30, 64)     55360
#
#  activation_16 (Activation)  (None, 5, 30, 30, 64)     0
#
#  batch_normalization_14 (Bat  (None, 5, 30, 30, 64)    256
#  chNormalization)
#
#  max_pooling3d_10 (MaxPoolin  (None, 2, 15, 15, 64)    0
#  g3D)
#
#  conv3d_11 (Conv3D)          (None, 2, 15, 15, 128)    221312
#
#  activation_17 (Activation)  (None, 2, 15, 15, 128)    0
#
#  batch_normalization_15 (Bat  (None, 2, 15, 15, 128)   512
#  chNormalization)
#
#  max_pooling3d_11 (MaxPoolin  (None, 1, 7, 7, 128)     0
#  g3D)
#
#  flatten_2 (Flatten)         (None, 6272)              0
#
#  dense_6 (Dense)             (None,
accuracy: 0.7500 - lr: 1.0000e-04
# Epoch 19/20
# 67/67 [==============================] - ETA: 0s - loss: 0.3512 - categorical_accuracy: 0.8612
# Epoch 19: val_loss did not improve from 0.38863
# 67/67 [==============================] - 139s 2s/step - loss: 0.3512 - categorical_accuracy: 0.8612 - val_loss: 0.4504 - val_categorical_accuracy: 0.8800 - lr: 1.0000e-04
# Epoch 20/20
# 67/67 [==============================] - ETA: 0s - loss: 0.3611 - categorical_accuracy: 0.8733
# Epoch 20: val_loss did not improve from 0.38863
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0001.
# 67/67 [==============================] - 138s 2s/step - loss: 0.3611 - categorical_accuracy: 0.8733 - val_loss: 0.4986 - val_categorical_accuracy: 0.8300 - lr: 1.0000e-04

# %%
plot_loss_accuracy(history)
# Out:
# dict_keys(['loss', 'categorical_accuracy', 'val_loss', 'val_categorical_accuracy', 'lr'])

# %% [markdown]
# ### Model 3

# %% [markdown]
# - 30 frames per video
# - (16, 32, 64, 128) filters
# - conv 3D layers
# - 256 dense layer
# - 128 dense layer
# - image size 160 by 160

# %%
num_epochs = 20 # choose the number of epochs
print ('# epochs =', num_epochs)
batch_size = 10  #experiment with the batch size
print ('# batch size =', batch_size)
num_frames = 30
print ('# num_frames per video =', num_frames)
height = 160
width = 160

model = conv3D(num_images=num_frames, height=160, width=160)

print (model.summary())
# Out:
# # epochs = 20
# # batch size = 10
# # num_frames per video = 30
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_12 (Conv3D)          (None, 30, 160, 160, 16)  1312
#
#  activation_21 (Activation)  (None, 30, 160, 160, 16)  0
#
#  batch_normalization_18 (Bat  (None, 30, 160, 160, 16)  64
#  chNormalization)
#
#  max_pooling3d_12 (MaxPoolin  (None, 15, 80, 80, 16)   0
#  g3D)
#
#  conv3d_13 (Conv3D)          (None, 15, 80, 80, 32)    13856
#
#  activation_22 (Activation)  (None, 15, 80, 80, 32)    0
#
#  batch_normalization_19 (Bat  (None, 15, 80, 80, 32)   128
#  chNormalization)
#
#  max_pooling3d_13 (MaxPoolin  (None, 7, 40, 40, 32)    0
#  g3D)
#
#  conv3d_14 (Conv3D)          (None, 7, 40, 40, 64)     55360
#
#  activation_23 (Activation)  (None, 7, 40, 40, 64)     0
#
#  batch_normalization_20 (Bat  (None, 7, 40, 40, 64)    256
#  chNormalization)
#
#  max_pooling3d_14 (MaxPoolin  (None, 3, 20, 20, 64)    0
#  g3D)
#
#  conv3d_15 (Conv3D)          (None, 3, 20, 20, 128)    221312
#
#  activation_24 (Activation)  (None, 3, 20, 20, 128)    0
#
#  batch_normalization_21 (Bat  (None, 3, 20, 20, 128)   512
#  chNormalization)
#
#  max_pooling3d_15 (MaxPoolin  (None, 1, 10, 10, 128)   0
#  g3D)
#
#  flatten_3 (Flatten)         (None, 12800)             0
#
#  dense_9 (Dense)             (None, 256)               3277056
#
#  activation_25 (Activation)  (None, 256)               0
#
#  batch_normalization_22 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_6 (Dropout)         (None, 256)               0
#
#  dense_10 (Dense)            (None, 128)               32896
#
#  activation_26 (Activation)  (None, 128)               0
#
#  batch_normalization_23 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_7 (Dropout)         (None, 128)               0
#
#  dense_11 (Dense)            (None, 5)                 645
#
#  activation_27 (Activation)  (None, 5)                 0
#
# =================================================================
# Total params: 3,604,933
# Trainable params: 3,603,685
# Non-trainable params: 1,248
# _________________________________________________________________
# None

# %% [markdown]
# The `steps_per_epoch` and `validation_steps` are used by `fit_generator` to decide the number of next() calls it need to make.
# Let us now fit the model. This will start training the model and with the help of the checkpoints, you'll be able to save the model at the end of each epoch.

# %%
callbacks_list = model_callbacks("model_conv3D_3")

steps_per_epoch, validation_steps = calculate_steps(num_train_sequences, num_val_sequences, batch_size)

train_generator = generate(train_path, train_doc, batch_size, num_images=num_frames, height=160, width=160)

val_generator   = generate(val_path, val_doc, batch_size, num_images=num_frames, height=160, width=160)

# %%
history = model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                              callbacks=callbacks_list, validation_data=val_generator, 
                              validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# /tmp/ipykernel_32/2794917941.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1,
# /tmp/ipykernel_32/300689100.py:45: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
# Epoch 1/20
# 65/67 [============================>.] - ETA: 7s - loss: 1.5897 - categorical_accuracy: 0.4569
# /tmp/ipykernel_32/300689100.py:74: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread(source_path+'/'+ t[folder + (num_batches*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
# 67/67 [==============================] - ETA: 0s - loss: 1.5810 - categorical_accuracy: 0.4600
# Epoch 1: val_loss improved from inf to 3.39346, saving model to model_conv3D_3_2023-11-0514_52_37.489401/model-00001-1.58102-0.46003-3.39346-0.17000.h5
# 67/67 [==============================] - 284s 4s/step - loss: 1.5810 - categorical_accuracy: 0.4600 - val_loss: 3.3935 - val_categorical_accuracy: 0.1700 - lr: 0.0010
# Epoch 2/20
# 67/67 [==============================] - ETA: 0s - loss: 1.4522 - categorical_accuracy: 0.4555
# Epoch 2: val_loss did not improve from 3.39346
# 67/67 [==============================] - 267s 4s/step - loss: 1.4522 - categorical_accuracy: 0.4555 - val_loss: 3.6448 - val_categorical_accuracy: 0.2100 - lr: 0.0010
# Epoch 3/20
# 67/67 [==============================] - ETA: 0s - loss:
accuracy: 0.6900 - lr: 1.0000e-04
# Epoch 13/20
# 67/67 [==============================] - ETA: 0s - loss: 0.4840 - categorical_accuracy: 0.8190
# Epoch 13: val_loss did not improve from 0.83936
# 67/67 [==============================] - 263s 4s/step - loss: 0.4840 - categorical_accuracy: 0.8190 - val_loss: 0.9138 - val_categorical_accuracy: 0.6300 - lr: 1.0000e-04
# Epoch 14/20
# 67/67 [==============================] - ETA: 0s - loss: 0.4638 - categorical_accuracy: 0.8311
# Epoch 14: val_loss improved from 0.83936 to 0.67436, saving model to model_conv3D_3_2023-11-0514_52_37.489401/model-00014-0.46378-0.83107-0.67436-0.76000.h5
# 67/67 [==============================] - 263s 4s/step - loss: 0.4638 - categorical_accuracy: 0.8311 - val_loss: 0.6744 - val_categorical_accuracy: 0.7600 - lr: 1.0000e-04
# Epoch 15/20
# 67/67 [==============================] - ETA: 0s - loss: 0.4058 - categorical_accuracy: 0.8416
# Epoch 15: val_loss did not improve from 0.67436
# 67/67 [==============================] - 265s 4s/step - loss: 0.4058 - categorical_accuracy: 0.8416 - val_loss: 0.7650 - val_categorical_accuracy: 0.6800 - lr: 1.0000e-04
# Epoch 16/20
# 67/67 [==============================] - ETA: 0s - loss: 0.4079 - categorical_accuracy: 0.8567
# Epoch 16: val_loss did not improve from 0.67436
# 67/67 [==============================] - 263s 4s/step - loss: 0.4079 - categorical_accuracy: 0.8567 - val_loss: 0.7044 - val_categorical_accuracy: 0.7200 - lr: 1.0000e-04
# Epoch 17/20
# 67/67 [==============================] - ETA: 0s - loss: 0.3748 - categorical_accuracy: 0.8627
# Epoch 17: val_loss improved from 0.67436 to 0.63546, saving model to model_conv3D_3_2023-11-0514_52_37.489401/model-00017-0.37476-0.86275-0.63546-0.72000.h5
# 67/67 [==============================] - 267s 4s/step - loss: 0.3748 - categorical_accuracy: 0.8627 - val_loss: 0.6355 - val_categorical_accuracy: 0.7200 - lr: 1.0000e-04
# Epoch 18/20
# 67/67 [==============================] - ETA: 0s - loss: 0.4135 - categorical_accuracy: 0.8522
# Epoch 18: val_loss did not improve from 0.63546
# 67/67 [==============================] - 264s 4s/step - loss: 0.4135 - categorical_accuracy: 0.8522 - val_loss: 0.8409 - val_categorical_accuracy: 0.7300 - lr: 1.0000e-04
# Epoch 19/20
# 67/67 [==============================] - ETA: 0s - loss: 0.4178 - categorical_accuracy: 0.8401
# Epoch 19: val_loss did not improve from 0.63546
# 67/67 [==============================] - 263s 4s/step - loss: 0.4178 - categorical_accuracy: 0.8401 - val_loss: 0.7526 - val_categorical_accuracy: 0.7300 - lr: 1.0000e-04
# Epoch 20/20
# 67/67 [==============================] - ETA: 0s - loss: 0.3157 - categorical_accuracy: 0.8824
# Epoch 20: val_loss did not improve from 0.63546
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0001.
# 67/67 [==============================] - 267s 4s/step - loss: 0.3157 - categorical_accuracy: 0.8824 - val_loss: 0.6834 - val_categorical_accuracy: 0.7600 - lr: 1.0000e-04

# %%
plot_loss_accuracy(history)
# Out:
# dict_keys(['loss', 'categorical_accuracy', 'val_loss', 'val_categorical_accuracy', 'lr'])

# %% [markdown]
# ### Model 4

# %% [markdown]
# - 20 frames per video
# - (16, 32, 64, 128 filters
# - Conv 3D layers
# - 256 dense layer
# - 128 dense layer
# - image size 160 by 160

# %%
num_epochs = 20 # choose the number of epochs
print ('# epochs =', num_epochs)
batch_size = 10  #experiment with the batch size
print ('# batch size =', batch_size)
num_frames = 20
print ('# num_frames per video =', num_frames)
height = 160
width = 160

model = conv3D(num_images=num_frames, height=160, width=160)

print (model.summary())
# Out:
# # epochs = 20
# # batch size = 10
# # num_frames per video = 20
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d (Conv3D)             (None, 20, 160, 160, 16)  1312
#
#  activation (Activation)     (None, 20, 160, 160, 16)  0
#
#  batch_normalization (BatchN  (None, 20, 160, 160, 16)  64
#  ormalization)
#
#  max_pooling3d (MaxPooling3D  (None, 10, 80, 80, 16)   0
#  )
#
#  conv3d_1 (Conv3D)           (None, 10, 80, 80, 32)    13856
#
#  activation_1 (Activation)   (None, 10, 80, 80, 32)    0
#
#  batch_normalization_1 (Batc  (None, 10, 80, 80, 32)   128
#  hNormalization)
#
#  max_pooling3d_1 (MaxPooling  (None, 5, 40, 40, 32)    0
#  3D)
#
#  conv3d_2 (Conv3D)           (None, 5, 40, 40, 64)     55360
#
#  activation_2 (Activation)   (None, 5, 40, 40, 64)     0
#
#  batch_normalization_2 (Batc  (None, 5, 40, 40, 64)    256
#  hNormalization)
#
#  max_pooling3d_2 (MaxPooling  (None, 2, 20, 20, 64)    0
#  3D)
#
#  conv3d_3 (Conv3D)           (None, 2, 20, 20, 128)    221312
#
#  activation_3 (Activation)   (None, 2, 20, 20, 128)    0
#
#  batch_normalization_3 (Batc  (None, 2, 20, 20, 128)   512
#  hNormalization)
#
#  max_pooling3d_3 (MaxPooling  (None, 1, 10, 10, 128)   0
#  3D)
#
#  flatten (Flatten)           (None, 12800)             0
#
#  dense (Dense)               (None, 256)               3277056
#
#  activation_4 (Activation)   (None, 256)               0
#
#  batch_normalization_4 (Batc  (None, 256)              1024
#  hNormalization)
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  activation_5 (Activation)   (None, 128)               0
#
#  batch_normalization_5 (Batc  (None, 128)              512
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 5)                 645
#
#  activation_6 (Activation)   (None, 5)                 0
#
# =================================================================
# Total params: 3,604,933
# Trainable params: 3,603,685
# Non-trainable params: 1,248
# _________________________________________________________________
# None

# %% [markdown]
# The `steps_per_epoch` and `validation_steps` are used by `fit_generator` to decide the number of next() calls it need to make.
# Let us now fit the model. This will start training the model and with the help of the checkpoints, you'll be able to save the model at the end of each epoch.

# %%
callbacks_list = model_callbacks("model_conv3D_4")

steps_per_epoch, validation_steps = calculate_steps(num_train_sequences, num_val_sequences, batch_size)

train_generator = generate(train_path, train_doc, batch_size, num_images=num_frames, height=160, width=160)

val_generator   = generate(val_path, val_doc, batch_size, num_images=num_frames, height=160, width=160)

# %%
history = model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                              callbacks=callbacks_list, validation_data=val_generator, 
                              validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# /tmp/ipykernel_33/2794917941.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1,
# /tmp/ipykernel_33/300689100.py:45: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
# Epoch 1/20
# 66/67 [============================>.] - ETA: 3s - loss: 1.5447 - categorical_accuracy: 0.4273
# /tmp/ipykernel_33/300689100.py:74: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread(source_path+'/'+ t[folder + (num_batches*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
# 67/67 [==============================] - ETA: 0s - loss: 1.5515 - categorical_accuracy: 0.4253
# Epoch 1: val_loss improved from inf to 5.03820, saving model to model_conv3D_4_2023-11-0603_56_42.650067/model-00001-1.55148-0.42534-5.03820-0.16000.h5
# 67/67 [==============================] - 261s 4s/step - loss: 1.5515 - categorical_accuracy: 0.4253 - val_loss: 5.0382 - val_categorical_accuracy: 0.1600 - lr: 0.0010
# Epoch 2/20
# 67/67 [==============================] - ETA: 0s - loss: 1.1352 - categorical_accuracy: 0.5897
# Epoch 2: val_loss did not improve from 5.03820
# 67/67 [==============================] - 198s 3s/step - loss: 1.1352 - categorical_accuracy: 0.5897 - val_loss: 7.5601 - val_categorical_accuracy: 0.1500 - lr: 0.0010
# Epoch 3/20
# 67/67 [==============================] - ETA: 0s - loss: 0.8756 - categorical_accuracy: 0.6863
# Epoch 3: val_loss did not improve from 5.03820
# 67/67 [==============================] - 202s 3s/step - loss: 0.8756 - categorical_accuracy: 0.6863 - val_loss: 6.4498 - val_categorical_accuracy: 0.1500 - lr: 0.0010
# Epoch 4/20
# 67/67 [==============================] - ETA: 0s - loss: 0.8900 - categorical_accuracy: 0.6772
# Epoch 4: val_loss did not improve from 5.03820
#
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 67/67 [==============================] - 208s 3s/step - loss: 0.8900 - categorical_accuracy: 0.6772 - val_loss: 5.6723 - val_categorical_accuracy: 0.2400 - lr: 0.0010
# Epoch 5/20
# 67/67 [==============================] - ETA: 0s - loss: 0.6364 - categorical_accuracy: 0.7662
# Epoch 5: val_loss improved from 5.03820 to 4.15817, saving model to model_conv3D_4_2023-11-0603_56_42.650067/model-00005-0.63644-0.76621-4.15817-0.24000.h5
# 67/67 [==============================] - 208s 3s/step - loss: 0.6364 - categorical_accuracy: 0.7662 - val_loss: 4.1582 - val_categorical_accuracy: 0.2400 - lr: 1.0000e-04
# Epoch 6/20
# 67/67 [==============================] - ETA: 0s - loss: 0.6539 - categorical_accuracy: 0.7541
# Epoch 6: val_loss improved from 4.15817 to 2.75316, saving model to model_conv3D_4_2023-11-0603_56_42.650067/model-00006-0.65394-0.75415-2.75316-0.27000.h5
# 67/67 [==============================] - 204s 3s/step - loss: 0.6539 - categorical_accuracy: 0.7541 - val_loss: 2.7532 - val_categorical_accuracy: 0.2700 - lr: 1.0000e-04
# Epoch 7/20
# 67/67 [==============================] - ETA: 0s - loss: 0.5336 - categorical_accuracy: 0.8100
# Epoch 7: val_loss improved from 2.75316 to 2.05679, saving model to model_conv3D_4_2023-11-0603_56_42.650067/model-00007-0.53362-0.80995-2.05679-0.35000.h5
# 67/67 [==============================] - 201s 3s/step - loss: 0.5336 - categorical_accuracy: 0.8100 - val_loss: 2.0568 - val_categorical_accuracy: 0.3500 - lr: 1.0000e-04
# Epoch 8/20
# 67/67 [==============================] - ETA: 0s - loss: 0.
accuracy: 0.8300 - lr: 1.0000e-04
# Epoch 18/20
# 67/67 [==============================] - ETA: 0s - loss: 0.2189 - categorical_accuracy: 0.9216
# Epoch 18: val_loss did not improve from 0.42279
# 67/67 [==============================] - 206s 3s/step - loss: 0.2189 - categorical_accuracy: 0.9216 - val_loss: 0.4680 - val_categorical_accuracy: 0.8600 - lr: 1.0000e-04
# Epoch 19/20
# 67/67 [==============================] - ETA: 0s - loss: 0.2213 - categorical_accuracy: 0.9216
# Epoch 19: val_loss did not improve from 0.42279
# 67/67 [==============================] - 210s 3s/step - loss: 0.2213 - categorical_accuracy: 0.9216 - val_loss: 0.6546 - val_categorical_accuracy: 0.7900 - lr: 1.0000e-04
# Epoch 20/20
# 67/67 [==============================] - ETA: 0s - loss: 0.2713 - categorical_accuracy: 0.9065
# Epoch 20: val_loss did not improve from 0.42279
# 67/67 [==============================] - 205s 3s/step - loss: 0.2713 - categorical_accuracy: 0.9065 - val_loss: 0.6641 - val_categorical_accuracy: 0.7300 - lr: 1.0000e-04

# %%
plot_loss_accuracy(history)
# Out:
# dict_keys(['loss', 'categorical_accuracy', 'val_loss', 'val_categorical_accuracy', 'lr'])

# %% [markdown]
# ### Model 5

# %% [markdown]
# - 30 frames per video
# - (16, 32, 64, 128) filters
# - Conv 3D layers
# - 256 dense layer
# - 128 dense layer
# - Random data transformations on training data set

# %%
num_epochs = 15 # choose the number of epochs
print ('# epochs =', num_epochs)
batch_size = 10  #experiment with the batch size
print ('# batch size =', batch_size)
num_frames = 30
print ('# num_frames per video =', num_frames)
height = 120
width = 120

model = conv3D(num_images=num_frames)

print (model.summary())
# Out:
# # epochs = 15
#
# # batch size = 10
#
# # num_frames per video = 30
#
# _________________________________________________________________
#
# Layer (type)                 Output Shape              Param #
#
# =================================================================
#
# conv3d_9 (Conv3D)            (None, 30, 120, 120, 16)  1312
#
# _________________________________________________________________
#
# activation_15 (Activation)   (None, 30, 120, 120, 16)  0
#
# _________________________________________________________________
#
# batch_normalization_13 (Batc (None, 30, 120, 120, 16)  64
#
# _________________________________________________________________
#
# max_pooling3d_9 (MaxPooling3 (None, 15, 60, 60, 16)    0
#
# _________________________________________________________________
#
# conv3d_10 (Conv3D)           (None, 15, 60, 60, 32)    13856
#
# _________________________________________________________________
#
# activation_16 (Activation)   (None, 15, 60, 60, 32)    0
#
# _________________________________________________________________
#
# batch_normalization_14 (Batc (None, 15, 60, 60, 32)    128
#
# _________________________________________________________________
#
# max_pooling3d_10 (MaxPooling (None, 7, 30, 30, 32)     0
#
# _________________________________________________________________
#
# conv3d_11 (Conv3D)           (None, 7, 30, 30, 64)     55360
#
# _________________________________________________________________
#
# activation_17 (Activation)   (None, 7, 30, 30, 64)     0
#
# _________________________________________________________________
#
# batch_normalization_15 (Batc (None, 7, 30, 30, 64)     256
#
# _________________________________________________________________
#
# max_pooling3d_11 (MaxPooling (None, 3, 15, 15, 64)     0
#
# _________________________________________________________________
#
# conv3d_12 (Conv3D)           (None, 3, 15, 15, 128)    221312
#
# _________________________________________________________________
#
# activation_18 (Activation)   (None, 3, 15, 15, 128)    0
#
# _________________________________________________________________
#
# batch_normalization_16 (Batc (None, 3, 15, 15, 128)    512
#
# _________________________________________________________________
#
# max_pooling3d_12 (MaxPooling (None, 1, 7, 7, 128)      0
#
# _________________________________________________________________
#
# flatten_3 (Flatten)          (None, 6272)              0
#
# _________________________________________________________________
#
# dense_7 (Dense)              (None, 256)               1605888
#
# _________________________________________________________________
#
# activation_19 (Activation)   (None, 256)               0
#
# _________________________________________________________________
#
# batch_normalization_17 (Batc (None, 256)               1024
#
# _________________________________________________________________
#
# dropout_5 (Dropout)          (None, 256)               0
#
# _________________________________________________________________
#
# dense_8 (Dense)              (None, 128)               32896
#
# _________________________________________________________________
#
# activation_20 (Activation)   (None, 128)               0
#
# _________________________________________________________________
#
# batch_normalization_18 (Batc (None, 128)               512
#
# _________________________________________________________________
#
# dropout_6 (Dropout)          (None, 128)               0
#
# _________________________________________________________________
#
# dense_9 (Dense)              (None, 5)                 645
#
# _________________________________________________________________
#
# activation_21 (Activation)   (None, 5)                 0
#
# =================================================================
#
# Total params: 1,933,765
#
# Trainable params: 1,932,517
#
# Non-trainable params: 1,248
#
# _________________________________________________________________
#
# None

# %%
callbacks_list = model_callbacks("model_conv3D_5")

steps_per_epoch, validation_steps = calculate_steps(num_train_sequences, num_val_sequences, batch_size)

train_generator = generate(train_path, train_doc, batch_size, augment=True, num_images=num_frames)

val_generator   = generate(val_path, val_doc, batch_size, num_images=num_frames)

# %%
history = model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                              callbacks=callbacks_list, validation_data=val_generator, 
                              validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Epoch 1/15
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/skimage/transform/_warps.py:105: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# 67/67 [==============================] - 195s 3s/step - loss: 1.7452 - categorical_accuracy: 0.3792 - val_loss: 2.6609 - val_categorical_accuracy: 0.3500
#
#
#
# Epoch 00001: val_loss improved from inf to 2.66091, saving model to model_conv3D_5_2020-08-1714_02_41.746177/model-00001-1.73287-0.38311-2.66091-0.35000.h5
#
# Epoch 2/15
#
# 67/67 [==============================] - 205s 3s/step - loss: 1.4684 - categorical_accuracy: 0.4428 - val_loss: 3.1332 - val_categorical_accuracy: 0.3300
#
#
#
# Epoch 00002: val_loss did not improve from 2.66091
#
# Epoch 3/15
#
# 67/67 [==============================] - 204s 3s/step - loss: 1.3028 - categorical_accuracy: 0.4931 - val_loss: 1.7819 - val_categorical_accuracy: 0.4600
#
#
#
# Epoch 00003: val_loss improved from 2.66091 to 1.78193, saving model to model_conv3D_5_2020-08-1714_02_41.746177/model-00003-1.29350-0.49472-1.78193-0.46000.h5
#
# Epoch 4/15
#
# 67/67 [==============================] - 206s 3s/step - loss: 1.4906 - categorical_accuracy: 0.4314 - val_loss: 1.5359 - val_categorical_accuracy: 0.4900
#
#
#
# Epoch 00004: val_loss improved from 1.78193 to 1.53594, saving model to model_conv3D_5_2020-08-1714_02_41.746177/model-00004-1.47364-0.43590-1.53594-0.49000.h5
#
# Epoch 5/15
#
# 67/67 [==============================] - 210s 3s/step - loss: 1.1504 - categorical_accuracy: 0.5334 - val_loss: 2.4798 - val_categorical_accuracy: 0.3100
#
#
#
# Epoch 00005: val_loss did not improve from 1.53594
#
# Epoch 6/15
#
# 67/67 [==============================] - 207s 3s/step - loss: 1.0375 - categorical_accuracy: 0.5961 - val_loss: 1.6863 - val_categorical_accuracy: 0.4600
#
#
#
# Epoch 00006: val_loss did not improve from 1.53594
#
# Epoch 7/15
#
# 67/67 [==============================] - 200s 3s/step - loss: 1.0056 - categorical_accuracy: 0.6014 - val_loss: 2.1630 - val_categorical_accuracy: 0.3100
#
#
#
# Epoch 00007: val_loss did not improve from 1.53594
#
#
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 8/15
#
# 67/67 [==============================] - 202s 3s/step - loss: 0.9481 - categorical_accuracy: 0.6349 - val_loss: 1.1315 - val_categorical_accuracy: 0.5700
#
#
#
# Epoch 00008: val_loss improved from 1.53594 to 1.13146, saving model to model_conv3D_5_2020-08-1714_02_41.746177/model-00008-0.94205-0.63801-1.13146-0.57000.h5
#
# Epoch 9/15
#
# 67/67 [==============================] - 201s 3s/step - loss: 0.8336 - categorical_accuracy: 0.6777 - val_loss: 1.1203 - val_categorical_accuracy: 0.6100
#
#
#
# Epoch 00009: val_loss improved from 1.13146 to 1.12027, saving model to model_conv3D_5_2020-08-1714_02_41.746177/model-00009-0.82449-0.68477-1.12027-0.61000.h5
#
# Epoch 10/15
#
# 67/67 [==============================] - 204s 3s/step - loss: 0.7821 - categorical_accuracy: 0.7240 - val_loss: 1.2588 - val_categorical_accuracy: 0.5600
#
#
#
# Epoch 00010: val_loss did not improve from 1.12027
#
# Epoch 11/15
#
# 67/67 [==============================] - 236s 4s/step - loss: 0.7067 - categorical_accuracy: 0.7074 - val_loss: 1.2274 - val_categorical_accuracy: 0.5800
#
#
#
# Epoch 00011: val_loss did not improve from 1.12027
#
# Epoch 12/15
#
# 67/67 [==============================] - 194s 3s/step - loss: 0.7110 - categorical_accuracy: 0.7373 - val_loss: 1.3252 - val_categorical_accuracy: 0.5700
#
#
#
# Epoch 00012: val_loss did not improve from 1.12027
#
#
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 13/15
#
# 67/67 [==============================] - 235s 4s/step - loss: 0.7347 - categorical_accuracy: 0.7373 - val_loss: 1.4371 - val_categorical_accuracy: 0.5600
#
#
#
# Epoch 00013: val_loss did not improve from 1.12027
#
# Epoch 14/15
#
# 67/67 [==============================] - 234s 3s/step - loss: 0.7134 - categorical_accuracy: 0.7210 - val_loss: 1.2538 - val_categorical_accuracy: 0.5600
#
#
#
# Epoch 00014: val_loss did not improve from 1.12027
#
# Epoch 15/15
#
# 67/67 [==============================] - 208s 3s/step - loss: 0.6587 - categorical_accuracy: 0.7577 - val_loss: 1.2814 - val_categorical_accuracy: 0.5900
#
#
#
# Epoch 00015: val_loss did not improve from 1.12027

# %%
plot_loss_accuracy(history)
# Out:
# dict_keys(['val_loss', 'val_categorical_accuracy', 'loss', 'categorical_accuracy', 'lr'])

# %% [markdown]
# The `steps_per_epoch` and `validation_steps` are used by `fit_generator` to decide the number of next() calls it need to make.
# Let us now fit the model. This will start training the model and with the help of the checkpoints, you'll be able to save the model at the end of each epoch.

# %% [markdown]
# ### TRANSFER LEARNING

# %% [markdown]
# ### MobileNet Conv2d and GRU

# %%
from keras.applications import mobilenet

def mobilenet_RNN(fine_tune=False, gru=False, lstm_gru_cells=128, dense_nodes=128, dropout=0.25, num_images=20, height=120, width=120):

    mobilenet_transfer = mobilenet.MobileNet(weights='imagenet', include_top=False)
    print("Number of layers in the pretrained mobilenet model: ", len(mobilenet_transfer.layers))

    if (fine_tune):
        # Fine-tune from this layer onwards
        fine_tune_at = 50
        # Freeze all the layers before the `fine_tune_at` layer
        for layer in mobilenet_transfer.layers[:fine_tune_at]:
            layer.trainable = False

    model = Sequential()
    model.add(TimeDistributed(mobilenet_transfer,input_shape=(num_images, height, width, 3)))
    model.add(TimeDistributed(BatchNormalization()))
    model.add(TimeDistributed(MaxPooling2D((2, 2))))
    model.add(TimeDistributed(Flatten()))
    if (gru):
        model.add(GRU(lstm_gru_cells))
    else:
        model.add(LSTM(lstm_gru_cells))
    model.add(Dropout(dropout))
    model.add(Dense(dense_nodes, activation='relu'))
    model.add(Dropout(dropout))
    model.add(Dense(num_classes, activation='softmax'))

    opt = optimizers.Adam() #write your optimizer
    model.compile(opt, loss='categorical_crossentropy', metrics=['categorical_accuracy'])    
    return model

# %% [markdown]
# ### Model 6

# %% [markdown]
# - Mobilenet (re train all weights)
# - GRU (128 cells)
# - 128 dense nodes

# %%
num_epochs = 20 # choose the number of epochs
print ('# epochs =', num_epochs)
batch_size = 10  #experiment with the batch size
print ('# batch size =', batch_size)
num_frames = 20
print ('# num frames per video =', num_frames)
height = 120
width = 120

model = mobilenet_RNN(num_images=num_frames, gru=True)
print (model.summary())
# Out:
# # epochs = 20
# # batch size = 10
# # num frames per video = 20
# Number of layers in the pretrained mobilenet model:  86
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed_4 (TimeDis  (None, 20, 3, 3, 1024)   3228864
#  tributed)
#
#  time_distributed_5 (TimeDis  (None, 20, 3, 3, 1024)   4096
#  tributed)
#
#  time_distributed_6 (TimeDis  (None, 20, 1, 1, 1024)   0
#  tributed)
#
#  time_distributed_7 (TimeDis  (None, 20, 1024)         0
#  tributed)
#
#  gru_1 (GRU)                 (None, 128)               443136
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_5 (Dense)             (None, 128)               16512
#
#  dropout_5 (Dropout)         (None, 128)               0
#
#  dense_6 (Dense)             (None, 5)                 645
#
# =================================================================
# Total params: 3,693,253
# Trainable params: 3,669,317
# Non-trainable params: 23,936
# _________________________________________________________________
# None

# %% [markdown]
# The `steps_per_epoch` and `validation_steps` are used by `fit_generator` to decide the number of next() calls it need to make.
# Let us now fit the model. This will start training the model and with the help of the checkpoints, you'll be able to save the model at the end of each epoch.

# %%
callbacks_list = model_callbacks("model_retrain_mobilenet_gru")

steps_per_epoch, validation_steps = calculate_steps(num_train_sequences, num_val_sequences, batch_size)

train_generator = generate(train_path, train_doc, batch_size, num_images=num_frames)

val_generator   = generate(val_path, val_doc, batch_size, num_images=num_frames)

# %%
history = model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                              callbacks=callbacks_list, validation_data=val_generator, 
                              validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# /tmp/ipykernel_33/2794917941.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1,
# /tmp/ipykernel_33/300689100.py:45: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
# Epoch 1/20
# 65/67 [============================>.] - ETA: 4s - loss: 1.1818 - categorical_accuracy: 0.5308
# /tmp/ipykernel_33/300689100.py:74: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread(source_path+'/'+ t[folder + (num_batches*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
# 67/67 [==============================] - ETA: 0s - loss: 1.1788 - categorical_accuracy: 0.5309
# Epoch 1: val_loss improved from inf to 1.07492, saving model to model_retrain_mobilenet_gru_2023-11-0603_56_42.650067/model-00001-1.17878-0.53092-1.07492-0.49000.h5
# 67/67 [==============================] - 169s 2s/step - loss: 1.1788 - categorical_accuracy: 0.5309 - val_loss: 1.0749 - val_categorical_accuracy: 0.4900 - lr: 0.0010
# Epoch 2/20
# 67/67 [==============================] - ETA: 0s - loss: 0.5256 - categorical_accuracy: 0.7994
# Epoch 2: val_loss improved from 1.07492 to 0.64953, saving model to model_retrain_mobilenet_gru_2023-11-0603_56_42.650067/model-00002-0.52560-0.79940-0.64953-0.74000.h5
# 67/67 [==============================] - 162s 2s/step - loss: 0.5256 - categorical_accuracy: 0.7994 - val_loss: 0.6495 - val_categorical_accuracy: 0.7400 - lr: 0.0010
# Epoch 3/20
# 67/67 [==============================] - ETA: 0s - loss: 0.3378 - categorical_accuracy: 0.8869
# Epoch 3: val_loss improved from 0.64953 to 0.24272, saving model to model_retrain_mobilenet_gru_2023-11-0603_56_42.650067/model-00003-0.33777-0.88688-0.24272-0.91000.h5
# 67/67 [==============================] - 163s 2s/step - loss: 0.3378 - categorical_accuracy: 0.8869 - val_loss: 0.2427 - val_categorical_accuracy: 0.9100 - lr: 0.0010
# Epoch 4/20
# 67/67 [==============================] - ETA: 0s - loss: 0.2351 - categorical_accuracy: 0.9246
# Epoch 4: val_loss did not improve from 0.24272
# 67/67 [==============================] - 164s 2s/step - loss: 0.2351 - categorical_accuracy: 0.9246 - val_loss: 0.4347 - val_categorical_accuracy: 0.9000 - lr: 0.0010
# Epoch 5/20
# 67/67 [==============================] - ETA: 0s - loss: 0.2047 - categorical_accuracy: 0.9306
# Epoch 5: val_loss did not improve from 0.24272
# 67/67 [==============================] - 163s 2s/step - loss: 0.2047 - categorical_accuracy: 0.9306 - val_loss: 0.3405 - val_categorical_accuracy: 0.9000 - lr: 0.0010
# Epoch 6/20
# 67/67 [==============================] - ETA: 0s - loss: 0.1963 - categorical_accuracy: 0.9367
# Epoch 6: val_loss did not improve from 0.24272
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 67/67 [==============================] - 161s 2s/step - loss: 0.1963 - categorical_accuracy: 0.9367 - val_loss: 0.6352 - val_categorical_accuracy: 0.7400 - lr: 0.0010
# Epoch 7/20
# 67/67 [==============================] - ETA: 0s - loss: 0.1888 - categorical_accuracy: 0.9517
# Epoch 7: val_loss improved from 0.24272 to 0.11066, saving model to model_retrain_mobilenet_gru_2023-11-0603_56_42.650067/model-00007-0.18876-0.95173-0.11066-0.95000.h5
# 67/67 [==============================] - 160s 2s/step - loss: 0.1888 - categorical_accuracy: 0.9517 - val_loss: 0.1107 - val_categorical_accuracy: 0.9500 - lr: 1.0000e-04
# Epoch 8/20
# 67/67 [==============================] - ETA: 0s - loss: 0.0819 - categorical_accuracy: 0.9774
# Epoch 8: val_loss improved from 0.11066 to 0.07704, saving model to model_retrain_mobilenet_gru_2023-11-0603_56_42.650067/model-00008-0.08192-0.97738-0.07704-0.99000.h5
# 67/67 [==============================] - 161s 2s/step - loss: 0.0819 - categorical_accuracy: 0.9774 - val_loss: 0.0770 - val_categorical_accuracy: 0.9900 - lr: 1.0000e-04
# Epoch 9/20
# 67/67 [==============================] - ETA: 0s - loss: 0.0487 - categorical_accuracy: 0.9894
# Epoch 9: val_loss did not improve from 0.07704
# 67/67 [==============================] - 160s 2s/step - loss: 0.0487 - categorical_accuracy: 0.9894 - val_loss: 0.0896 - val_categorical_accuracy: 0.9700 - lr: 1.0000e-04
# Epoch 10/20
# 67/67 [==============================] - ETA: 0s - loss: 0.0360 - categorical_accuracy: 0.9955
# Epoch 10: val_loss did not improve from 0.07704
# 67/67 [==============================] - 160s 2s/step - loss: 0.0360 - categorical_accuracy: 0.9955 - val_loss: 0.1607 - val_categorical_accuracy: 0.9500 - lr: 1.0000e-04
# Epoch 11/20
# 67/67 [==============================] - ETA: 0s - loss: 0.0529 - categorical_accuracy: 0.9789
# Epoch 11: val_loss did not improve from 0.07704
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0001.
# 67/67 [==============================] - 161s 2s/step - loss: 0.0529 - categorical_accuracy: 0.9789 - val_loss: 0.1103 - val_categorical_accuracy: 0.9700 - lr: 1.0000e-04
# Epoch 12/20
# 67/67 [==============================] - ETA: 0s - loss: 0.0291 - categorical_accuracy: 0.9910
# Epoch 12: val_loss did not improve from 0.07704
# 67/67 [==============================] - 160s 2s/step - loss: 0.0291 - categorical_accuracy: 0.9910 - val_loss: 0.1158 - val_categorical_accuracy: 0.9500 - lr: 1.0000e-04
# Epoch 13/20
# 67/67 [==============================] - ETA: 0s - loss: 0.0298 - categorical_accuracy: 0.9879
# Epoch 13: val_loss did not improve from 0.07704
# 67/67 [==============================] - 159s 2s/step - loss: 0.0298 - categorical_accuracy: 0.9879 - val_loss: 0.0940 - val_categorical_accuracy: 0.9700 - lr: 1.0000e-04
# Epoch 14/20
# 67/67 [==============================] - ETA: 0s - loss: 0.0225 - categorical_accuracy: 0.9955
# Epoch 14: val_loss did not improve from 0.07704
# 67/67 [==============================] - 179s 3s/step - loss: 0.0225 - categorical_accuracy: 0.9955 - val_loss: 0.1213 - val_categorical_accuracy: 0.9600 - lr: 1.0000e-04
# Epoch 15/20
# 67/67 [==============================] - ETA: 0s - loss: 0.0167 - categorical_accuracy: 0.9955
# Epoch 15: val_loss did not improve from 0.07704
# 67/67 [==============================] - 161s 2s/step - loss: 0.0167 - categorical_accuracy: 0.9955 - val_loss: 0.0966 - val_categorical_accuracy: 0.9800 - lr: 1.0000e-04
# Epoch 16/20
# 67/67 [==============================] - ETA: 0s - loss: 0.0295 - categorical_accuracy: 0.9940
# Epoch 16: val_loss did not improve from 0.07704
# 67/67 [==============================] - 159s 2s/step - loss: 0.0295 - categorical_accuracy: 0.9940 - val_loss: 0.2166 - val_categorical_accuracy: 0.9400 - lr: 1.0000e-04
# Epoch 17/20
# 67/67 [==============================] - ETA: 0s - loss: 0.0081 - categorical_accuracy: 1.0000
# Epoch 17: val_loss did not improve from 0.07704
# 67/67 [==============================] - 159s 2s/step - loss: 0.0081 - categorical_accuracy: 1.0000 - val_loss: 0.1083 - val_categorical_accuracy: 0.9700 - lr: 1.0000e-04
# Epoch 18/20
# 67/67 [==============================] - ETA: 0s - loss: 0.0109 - categorical_accuracy: 0.9970
# Epoch 18: val_loss did not improve from 0.07704
# 67/67 [==============================] - 159s 2s/step - loss: 0.0109 - categorical_accuracy: 0.9970 - val_loss: 0.0970 - val_categorical_accuracy: 0.9800 - lr: 1.0000e-04
# Epoch 19/20
# 67/67 [==============================] - ETA: 0s - loss: 0.0182 - categorical_accuracy: 0.9955
# Epoch 19: val_loss improved from 0.07704 to 0.06293, saving model to model_retrain_mobilenet_gru_2023-11-0603_56_42.650067/model-00019-0.01819-0.99548-0.06293-0.97000.h5
# 67/67 [==============================] - 160s 2s/step - loss: 0.0182 - categorical_accuracy: 0.9955 - val_loss: 0.0629 - val_categorical_accuracy: 0.9700 - lr: 1.0000e-04
# Epoch 20/20
# 67/67 [==============================] - ETA: 0s - loss: 0.0119 - categorical_accuracy: 0.9970
# Epoch 20: val_loss improved from 0.06293 to 0.04554, saving model to model_retrain_mobilenet_gru_2023-11-0603_56_42.650067/model-00020-0.01188-0.99698-0.04554-0.98000.h5
# 67/67 [==============================] - 160s 2s/step - loss: 0.0119 - categorical_accuracy: 0.9970 - val_loss: 0.0455 - val_categorical_accuracy: 0.9800 - lr: 1.0000e-04

# %%
plot_loss_accuracy(history)
# Out:
# dict_keys(['loss', 'categorical_accuracy', 'val_loss', 'val_categorical_accuracy', 'lr'])

# %% [markdown]
# ### Model 7

# %% [markdown]
# - Mobilenet (re train all weights)
# - GRU (128 cells)
# - 128 dense nodes
# - Random data transformations on training data set

# %%
num_epochs = 20 # choose the number of epochs
print ('# epochs =', num_epochs)
batch_size = 10  #experiment with the batch size
print ('# batch size =', batch_size)
num_frames = 30
print ('# num frames per video =', num_frames)
height = 120
width = 120

model = mobilenet_RNN(gru=True, num_images=num_frames)
print(model.summary())
# Out:
# # epochs = 20
# # batch size = 10
# # num frames per video = 30
# Number of layers in the pretrained mobilenet model:  86
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed_8 (TimeDis  (None, 30, 3, 3, 1024)   3228864
#  tributed)
#
#  time_distributed_9 (TimeDis  (None, 30, 3, 3, 1024)   4096
#  tributed)
#
#  time_distributed_10 (TimeDi  (None, 30, 1, 1, 1024)   0
#  stributed)
#
#  time_distributed_11 (TimeDi  (None, 30, 1024)         0
#  stributed)
#
#  gru_2 (GRU)                 (None, 128)               443136
#
#  dropout_6 (Dropout)         (None, 128)               0
#
#  dense_7 (Dense)             (None, 128)               16512
#
#  dropout_7 (Dropout)         (None, 128)               0
#
#  dense_8 (Dense)             (None, 5)                 645
#
# =================================================================
# Total params: 3,693,253
# Trainable params: 3,669,317
# Non-trainable params: 23,936
# _________________________________________________________________
# None

# %%
callbacks_list = model_callbacks("model_retrain_mobilenet_gru")

steps_per_epoch, validation_steps = calculate_steps(num_train_sequences, num_val_sequences, batch_size)

train_generator = generate(train_path, train_doc, batch_size, augment=True, num_images=num_frames)

val_generator   = generate(val_path, val_doc, batch_size, num_images=num_frames)

# %%
history = model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                              callbacks=callbacks_list, validation_data=val_generator, 
                              validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# /tmp/ipykernel_33/2794917941.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1,
# /tmp/ipykernel_33/300689100.py:45: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
# Epoch 1/20
# 65/67 [============================>.] - ETA: 8s - loss: 1.1772 - categorical_accuracy: 0.5046
# /tmp/ipykernel_33/300689100.py:74: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread(source_path+'/'+ t[folder + (num_batches*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
# 67/67 [==============================] - ETA: 0s - loss: 1
- val_categorical_accuracy: 0.9200 - lr: 1.0000e-04
# Epoch 13/20
# 67/67 [==============================] - ETA: 0s - loss: 0.1058 - categorical_accuracy: 0.9698
# Epoch 13: val_loss did not improve from 0.17286
# 67/67 [==============================] - 275s 4s/step - loss: 0.1058 - categorical_accuracy: 0.9698 - val_loss: 0.1864 - val_categorical_accuracy: 0.9300 - lr: 1.0000e-04
# Epoch 14/20
# 67/67 [==============================] - ETA: 0s - loss: 0.0731 - categorical_accuracy: 0.9789
# Epoch 14: val_loss improved from 0.17286 to 0.14316, saving model to model_retrain_mobilenet_gru_2023-11-0603_56_42.650067/model-00014-0.07311-0.97888-0.14316-0.96000.h5
# 67/67 [==============================] - 268s 4s/step - loss: 0.0731 - categorical_accuracy: 0.9789 - val_loss: 0.1432 - val_categorical_accuracy: 0.9600 - lr: 1.0000e-04
# Epoch 15/20
# 67/67 [==============================] - ETA: 0s - loss: 0.0346 - categorical_accuracy: 0.9970
# Epoch 15: val_loss improved from 0.14316 to 0.13984, saving model to model_retrain_mobilenet_gru_2023-11-0603_56_42.650067/model-00015-0.03462-0.99698-0.13984-0.96000.h5
# 67/67 [==============================] - 274s 4s/step - loss: 0.0346 - categorical_accuracy: 0.9970 - val_loss: 0.1398 - val_categorical_accuracy: 0.9600 - lr: 1.0000e-04
# Epoch 16/20
# 67/67 [==============================] - ETA: 0s - loss: 0.0386 - categorical_accuracy: 0.9925
# Epoch 16: val_loss improved from 0.13984 to 0.10008, saving model to model_retrain_mobilenet_gru_2023-11-0603_56_42.650067/model-00016-0.03858-0.99246-0.10008-0.95000.h5
# 67/67 [==============================] - 290s 4s/step - loss: 0.0386 - categorical_accuracy: 0.9925 - val_loss: 0.1001 - val_categorical_accuracy: 0.9500 - lr: 1.0000e-04
# Epoch 17/20
# 67/67 [==============================] - ETA: 0s - loss: 0.0314 - categorical_accuracy: 0.9940
# Epoch 17: val_loss did not improve from 0.10008
# 67/67 [==============================] - 295s 4s/step - loss: 0.0314 - categorical_accuracy: 0.9940 - val_loss: 0.1099 - val_categorical_accuracy: 0.9600 - lr: 1.0000e-04
# Epoch 18/20
# 67/67 [==============================] - ETA: 0s - loss: 0.0340 - categorical_accuracy: 0.9894
# Epoch 18: val_loss improved from 0.10008 to 0.09902, saving model to model_retrain_mobilenet_gru_2023-11-0603_56_42.650067/model-00018-0.03402-0.98944-0.09902-0.97000.h5
# 67/67 [==============================] - 290s 4s/step - loss: 0.0340 - categorical_accuracy: 0.9894 - val_loss: 0.0990 - val_categorical_accuracy: 0.9700 - lr: 1.0000e-04
# Epoch 19/20
# 67/67 [==============================] - ETA: 0s - loss: 0.0223 - categorical_accuracy: 0.9955
# Epoch 19: val_loss improved from 0.09902 to 0.08207, saving model to model_retrain_mobilenet_gru_2023-11-0603_56_42.650067/model-00019-0.02229-0.99548-0.08207-0.96000.h5
# 67/67 [==============================] - 280s 4s/step - loss: 0.0223 - categorical_accuracy: 0.9955 - val_loss: 0.0821 - val_categorical_accuracy: 0.9600 - lr: 1.0000e-04
# Epoch 20/20
# 67/67 [==============================] - ETA: 0s - loss: 0.0211 - categorical_accuracy: 0.9955
# Epoch 20: val_loss did not improve from 0.08207
# 67/67 [==============================] - 276s 4s/step - loss: 0.0211 - categorical_accuracy: 0.9955 - val_loss: 0.0848 - val_categorical_accuracy: 0.9700 - lr: 1.0000e-04

# %%
plot_loss_accuracy(history)
# Out:
# dict_keys(['loss', 'categorical_accuracy', 'val_loss', 'val_categorical_accuracy', 'lr'])

# %% [markdown]
# ### Model 8

# %% [markdown]
# - Mobilenet (fine tune)
# - GRU (128 cells)
# - 128 dense nodes

# %%
num_epochs = 20 # choose the number of epochs
print ('# epochs =', num_epochs)
batch_size = 10  #experiment with the batch size
print ('# batch size =', batch_size)
num_frames = 20
print ('# num frames per video =', num_frames)
height = 120
width = 120

model = mobilenet_RNN(fine_tune=True, gru=True, num_images=num_frames)
print(model.summary())
# Out:
# # epochs = 20
# # batch size = 10
# # num frames per video = 20
# Number of layers in the pretrained mobilenet model:  86
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed_12 (TimeDi  (None, 20, 3, 3, 1024)   3228864
#  stributed)
#
#  time_distributed_13 (TimeDi  (None, 20, 3, 3, 1024)   4096
#  stributed)
#
#  time_distributed_14 (TimeDi  (None, 20, 1, 1, 1024)   0
#  stributed)
#
#  time_distributed_15 (TimeDi  (None, 20, 1024)         0
#  stributed)
#
#  gru_3 (GRU)                 (None, 128)               443136
#
#  dropout_8 (Dropout)         (None, 128)               0
#
#  dense_9 (Dense)             (None, 128)               16512
#
#  dropout_9 (Dropout)         (None, 128)               0
#
#  dense_10 (Dense)            (None, 5)                 645
#
# =================================================================
# Total params: 3,693,253
# Trainable params: 3,126,789
# Non-trainable params: 566,464
# _________________________________________________________________
# None

# %%
callbacks_list = model_callbacks("model_finetune_mobilenet_gru")

steps_per_epoch, validation_steps = calculate_steps(num_train_sequences, num_val_sequences, batch_size)

train_generator = generate(train_path, train_doc, batch_size, num_images=num_frames)

val_generator   = generate(val_path, val_doc, batch_size, num_images=num_frames)

# %%
history = model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                              callbacks=callbacks_list, validation_data=val_generator, 
                              validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# /tmp/ipykernel_33/2794917941.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1,
# /tmp/ipykernel_33/300689100.py:45: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
# Epoch 1/20
# 65/67 [============================>.] - ETA: 4s - loss: 1.2127 - categorical_accuracy: 0.5062
# /tmp/ipykernel_33/300689100.py:74: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread(source_path+'/'+ t[folder + (num_batches*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
# 67/67 [==============================] - ETA: 0s - loss: 1.2021 - categorical_accuracy: 0.5113
# Epoch 1: val_loss improved from inf to 1.01606, saving model to model_finetune_mobilenet_gru_2023-11-0603_56_42.650067/model-00001-1.20206-0.51131-1.01606-0.53000.h5
# 67/67 [==============================] - 171s 3s/step - loss: 1.2021 - categorical_accuracy: 0.5113 - val_loss: 1.0161 - val_categorical_accuracy: 0.5300 - lr: 0.0010
# Epoch 2/20
# 67/67 [==============================] - ETA: 0s - loss:
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0001.
# 67/67 [==============================] - 172s 3s/step - loss: 0.0183 - categorical_accuracy: 0.9970 - val_loss: 0.3394 - val_categorical_accuracy: 0.9200 - lr: 1.0000e-04
# Epoch 13/20
# 67/67 [==============================] - ETA: 0s - loss: 0.0115 - categorical_accuracy: 1.0000
# Epoch 13: val_loss did not improve from 0.22682
# 67/67 [==============================] - 164s 2s/step - loss: 0.0115 - categorical_accuracy: 1.0000 - val_loss: 0.2401 - val_categorical_accuracy: 0.9500 - lr: 1.0000e-04
# Epoch 14/20
# 67/67 [==============================] - ETA: 0s - loss: 0.0238 - categorical_accuracy: 0.9925
# Epoch 14: val_loss did not improve from 0.22682
# 67/67 [==============================] - 174s 3s/step - loss: 0.0238 - categorical_accuracy: 0.9925 - val_loss: 0.2511 - val_categorical_accuracy: 0.9400 - lr: 1.0000e-04
# Epoch 15/20
# 67/67 [==============================] - ETA: 0s - loss: 0.0213 - categorical_accuracy: 0.9955
# Epoch 15: val_loss improved from 0.22682 to 0.20036, saving model to model_finetune_mobilenet_gru_2023-11-0603_56_42.650067/model-00015-0.02125-0.99548-0.20036-0.94000.h5
# 67/67 [==============================] - 176s 3s/step - loss: 0.0213 - categorical_accuracy: 0.9955 - val_loss: 0.2004 - val_categorical_accuracy: 0.9400 - lr: 1.0000e-04
# Epoch 16/20
# 67/67 [==============================] - ETA: 0s - loss: 0.0113 - categorical_accuracy: 0.9955
# Epoch 16: val_loss did not improve from 0.20036
# 67/67 [==============================] - 169s 3s/step - loss: 0.0113 - categorical_accuracy: 0.9955 - val_loss: 0.3053 - val_categorical_accuracy: 0.9200 - lr: 1.0000e-04
# Epoch 17/20
# 67/67 [==============================] - ETA: 0s - loss: 0.0102 - categorical_accuracy: 0.9970
# Epoch 17: val_loss did not improve from 0.20036
# 67/67 [==============================] - 179s 3s/step - loss: 0.0102 - categorical_accuracy: 0.9970 - val_loss: 0.2283 - val_categorical_accuracy: 0.9500 - lr: 1.0000e-04
# Epoch 18/20
# 67/67 [==============================] - ETA: 0s - loss: 0.0072 - categorical_accuracy: 0.9970
# Epoch 18: val_loss did not improve from 0.20036
# 67/67 [==============================] - 162s 2s/step - loss: 0.0072 - categorical_accuracy: 0.9970 - val_loss: 0.2645 - val_categorical_accuracy: 0.9300 - lr: 1.0000e-04
# Epoch 19/20
# 67/67 [==============================] - ETA: 0s - loss: 0.0263 - categorical_accuracy: 0.9925
# Epoch 19: val_loss did not improve from 0.20036
# 67/67 [==============================] - 161s 2s/step - loss: 0.0263 - categorical_accuracy: 0.9925 - val_loss: 0.2701 - val_categorical_accuracy: 0.9200 - lr: 1.0000e-04
# Epoch 20/20
# 67/67 [==============================] - ETA: 0s - loss: 0.0039 - categorical_accuracy: 1.0000
# Epoch 20: val_loss did not improve from 0.20036
# 67/67 [==============================] - 165s 2s/step - loss: 0.0039 - categorical_accuracy: 1.0000 - val_loss: 0.2352 - val_categorical_accuracy: 0.9300 - lr: 1.0000e-04

# %%
plot_loss_accuracy(history)
# Out:
# dict_keys(['loss', 'categorical_accuracy', 'val_loss', 'val_categorical_accuracy', 'lr'])

# %% [markdown]
# ### Model 9

# %% [markdown]
#  - Mobilenet (re train all wieghts)
#  - LSTM (128 cells)
#  - 128 dense nodes

# %%
num_epochs = 20 # choose the number of epochs
print ('# epochs =', num_epochs)
batch_size = 10  #experiment with the batch size
print ('# batch size =', batch_size)
num_frames = 20
print ('# num frames per video =', num_frames)
height = 120
width = 120

model = mobilenet_RNN(fine_tune=False, gru=False, num_images=num_frames)
print(model.summary())
# Out:
# # epochs = 20
# # batch size = 10
# # num frames per video = 20
# Number of layers in the pretrained mobilenet model:  86
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed_16 (TimeDi  (None, 20, 3, 3, 1024)   3228864
#  stributed)
#
#  time_distributed_17 (TimeDi  (None, 20, 3, 3, 1024)   4096
#  stributed)
#
#  time_distributed_18 (TimeDi  (None, 20, 1, 1, 1024)   0
#  stributed)
#
#  time_distributed_19 (TimeDi  (None, 20, 1024)         0
#  stributed)
#
#  lstm (LSTM)                 (None, 128)               590336
#
#  dropout_10 (Dropout)        (None, 128)               0
#
#  dense_11 (Dense)            (None, 128)               16512
#
#  dropout_11 (Dropout)        (None, 128)               0
#
#  dense_12 (Dense)            (None, 5)                 645
#
# =================================================================
# Total params: 3,840,453
# Trainable params: 3,816,517
# Non-trainable params: 23,936
# _________________________________________________________________
# None

# %%
callbacks_list = model_callbacks("model_retrain_mobilenet_lstm")

steps_per_epoch, validation_steps = calculate_steps(num_train_sequences, num_val_sequences, batch_size)

train_generator = generate(train_path, train_doc, batch_size, num_images=num_frames)

val_generator   = generate(val_path, val_doc, batch_size, num_images=num_frames)

# %%
history = model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                              callbacks=callbacks_list, validation_data=val_generator, 
                              validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# /tmp/ipykernel_33/2794917941.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1,
# /tmp/ipykernel_33/300689100.py:45: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
# Epoch 1/20
# 65/67 [============================>.] - ETA: 4s - loss: 1.2886 - categorical_accuracy: 0.4600
# /tmp/ipykernel_33/300689100.py:74: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread(source_path+'/'+ t[folder + (num_batches*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
# 67/67 [==============================] - ETA: 0s - loss: 1.2800 - categorical_accuracy: 0.4630
# Epoch 1: val_loss improved from inf to 0.84360, saving model to model_retrain_mobilenet_lstm_2023-11-0603_56_42.650067/model-00001-1.28004-0.46305-0.84360-0.65000.h5
# 67/67 [==============================] - 170s 2s/step - loss: 1.2800 - categorical_accuracy: 0.4630 - val_loss: 0.8436 - val_categorical_accuracy: 0.6500 - lr: 0.0010
# Epoch 2/20
# 67/67 [==============================] - ETA: 0s - loss: 0.
- val_categorical_accuracy: 0.9300 - lr: 1.0000e-04
# Epoch 14/20
# 67/67 [==============================] - ETA: 0s - loss: 0.1343 - categorical_accuracy: 0.9608
# Epoch 14: val_loss did not improve from 0.17263
# 67/67 [==============================] - 161s 2s/step - loss: 0.1343 - categorical_accuracy: 0.9608 - val_loss: 0.2763 - val_categorical_accuracy: 0.9100 - lr: 1.0000e-04
# Epoch 15/20
# 67/67 [==============================] - ETA: 0s - loss: 0.1231 - categorical_accuracy: 0.9578
# Epoch 15: val_loss improved from 0.17263 to 0.16803, saving model to model_retrain_mobilenet_lstm_2023-11-0603_56_42.650067/model-00015-0.12309-0.95777-0.16803-0.96000.h5
# 67/67 [==============================] - 165s 2s/step - loss: 0.1231 - categorical_accuracy: 0.9578 - val_loss: 0.1680 - val_categorical_accuracy: 0.9600 - lr: 1.0000e-04
# Epoch 16/20
# 67/67 [==============================] - ETA: 0s - loss: 0.1431 - categorical_accuracy: 0.9578
# Epoch 16: val_loss did not improve from 0.16803
# 67/67 [==============================] - 160s 2s/step - loss: 0.1431 - categorical_accuracy: 0.9578 - val_loss: 0.2243 - val_categorical_accuracy: 0.9400 - lr: 1.0000e-04
# Epoch 17/20
# 67/67 [==============================] - ETA: 0s - loss: 0.1380 - categorical_accuracy: 0.9638
# Epoch 17: val_loss did not improve from 0.16803
# 67/67 [==============================] - 162s 2s/step - loss: 0.1380 - categorical_accuracy: 0.9638 - val_loss: 0.2877 - val_categorical_accuracy: 0.9100 - lr: 1.0000e-04
# Epoch 18/20
# 67/67 [==============================] - ETA: 0s - loss: 0.0991 - categorical_accuracy: 0.9668
# Epoch 18: val_loss did not improve from 0.16803
# 67/67 [==============================] - 161s 2s/step - loss: 0.0991 - categorical_accuracy: 0.9668 - val_loss: 0.2144 - val_categorical_accuracy: 0.9400 - lr: 1.0000e-04
# Epoch 19/20
# 67/67 [==============================] - ETA: 0s - loss: 0.1065 - categorical_accuracy: 0.9744
# Epoch 19: val_loss did not improve from 0.16803
# 67/67 [==============================] - 164s 2s/step - loss: 0.1065 - categorical_accuracy: 0.9744 - val_loss: 0.2832 - val_categorical_accuracy: 0.9200 - lr: 1.0000e-04
# Epoch 20/20
# 67/67 [==============================] - ETA: 0s - loss: 0.0866 - categorical_accuracy: 0.9759
# Epoch 20: val_loss did not improve from 0.16803
# 67/67 [==============================] - 168s 3s/step - loss: 0.0866 - categorical_accuracy: 0.9759 - val_loss: 0.2360 - val_categorical_accuracy: 0.9400 - lr: 1.0000e-04

# %%
plot_loss_accuracy(history)
# Out:
# dict_keys(['loss', 'categorical_accuracy', 'val_loss', 'val_categorical_accuracy', 'lr'])

# %% [markdown]
# ### Model 10(Final Model)

# %% [markdown]
# - Mobilenet (re train all weights)
# - 64 dense nodes

# %%
num_epochs = 20 # choose the number of epochs
print ('# epochs =', num_epochs)
batch_size = 10  #experiment with the batch size
print ('# batch size =', batch_size)
num_frames = 20
print ('# num frames per video =', num_frames)
height = 120
width = 120

model = mobilenet_RNN(fine_tune=False, gru=True, num_images=num_frames, lstm_gru_cells=128, dense_nodes=64)
print(model.summary())
# Out:
# # epochs = 20
# # batch size = 10
# # num frames per video = 20
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet/mobilenet_1_0_224_tf_no_top.h5
# 17225924/17225924 [==============================] - 0s 0us/step
# Number of layers in the pretrained mobilenet model:  86
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed (TimeDistr  (None, 20, 3, 3, 1024)   3228864
#  ibuted)
#
#  time_distributed_1 (TimeDis  (None, 20, 3, 3, 1024)   4096
#  tributed)
#
#  time_distributed_2 (TimeDis  (None, 20, 1, 1, 1024)   0
#  tributed)
#
#  time_distributed_3 (TimeDis  (None, 20, 1024)         0
#  tributed)
#
#  gru (GRU)                   (None, 128)               443136
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense (Dense)               (None, 64)                8256
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 3,684,677
# Trainable params: 3,660,741
# Non-trainable params: 23,936
# _________________________________________________________________
# None

# %%
callbacks_list = model_callbacks("model_retrain_mobilenet_gru_64")

steps_per_epoch, validation_steps = calculate_steps(num_train_sequences, num_val_sequences, batch_size)

train_generator = generate(train_path, train_doc, batch_size, num_images=num_frames)

val_generator   = generate(val_path, val_doc, batch_size, num_images=num_frames)

# %%
history = model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                              callbacks=callbacks_list, validation_data=val_generator,
                              validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# /tmp/ipykernel_32/4147385776.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1,
# /tmp/ipykernel_32/490613900.py:45: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
# Epoch 1/20
# 65/67 [============================>.] - ETA: 6s - loss: 1.3641 - categorical_accuracy: 0.4523
# /tmp/ipykernel_32/490613900.py:74: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread(source_path+'/'+ t[folder + (num_batches*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
# 67/67 [==============================] - ETA: 0s - loss: 1.3563 - categorical_accuracy: 0.4555
# Epoch 1: val_loss improved from inf to 0.93411, saving model to model_retrain_mobilenet_gru_64_2023-11-0616_51_17.626802/model-00001-1.35625-0.45551-0.93411-0.60000.h5
# 67/67 [==============================] - 254s 4s/step - loss: 1.3563 - categorical_accuracy: 0.4555 - val_loss: 0.9341 - val_categorical_accuracy: 0.6000 - lr: 0.0010
# Epoch
20
# 67/67 [==============================] - ETA: 0s - loss: 0.1821 - categorical_accuracy: 0.9472
# Epoch 11: val_loss did not improve from 0.20463
# 67/67 [==============================] - 143s 2s/step - loss: 0.1821 - categorical_accuracy: 0.9472 - val_loss: 0.4395 - val_categorical_accuracy: 0.8500 - lr: 0.0010
# Epoch 12/20
# 67/67 [==============================] - ETA: 0s - loss: 0.1838 - categorical_accuracy: 0.9351
# Epoch 12: val_loss did not improve from 0.20463
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 67/67 [==============================] - 142s 2s/step - loss: 0.1838 - categorical_accuracy: 0.9351 - val_loss: 0.2485 - val_categorical_accuracy: 0.8800 - lr: 0.0010
# Epoch 13/20
# 67/67 [==============================] - ETA: 0s - loss: 0.0892 - categorical_accuracy: 0.9819
# Epoch 13: val_loss improved from 0.20463 to 0.11616, saving model to model_retrain_mobilenet_gru_64_2023-11-0616_51_17.626802/model-00013-0.08922-0.98190-0.11616-0.95000.h5
# 67/67 [==============================] - 141s 2s/step - loss: 0.0892 - categorical_accuracy: 0.9819 - val_loss: 0.1162 - val_categorical_accuracy: 0.9500 - lr: 1.0000e-04
# Epoch 14/20
# 67/67 [==============================] - ETA: 0s - loss: 0.0631 - categorical_accuracy: 0.9894
# Epoch 14: val_loss improved from 0.11616 to 0.09032, saving model to model_retrain_mobilenet_gru_64_2023-11-0616_51_17.626802/model-00014-0.06310-0.98944-0.09032-0.96000.h5
# 67/67 [==============================] - 144s 2s/step - loss: 0.0631 - categorical_accuracy: 0.9894 - val_loss: 0.0903 - val_categorical_accuracy: 0.9600 - lr: 1.0000e-04
# Epoch 15/20
# 67/67 [==============================] - ETA: 0s - loss: 0.0488 - categorical_accuracy: 0.9879
# Epoch 15: val_loss did not improve from 0.09032
# 67/67 [==============================] - 144s 2s/step - loss: 0.0488 - categorical_accuracy: 0.9879 - val_loss: 0.1175 - val_categorical_accuracy: 0.9500 - lr: 1.0000e-04
# Epoch 16/20
# 67/67 [==============================] - ETA: 0s - loss: 0.0340 - categorical_accuracy: 0.9910
# Epoch 16: val_loss did not improve from 0.09032
# 67/67 [==============================] - 143s 2s/step - loss: 0.0340 - categorical_accuracy: 0.9910 - val_loss: 0.1049 - val_categorical_accuracy: 0.9300 - lr: 1.0000e-04
# Epoch 17/20
# 67/67 [==============================] - ETA: 0s - loss: 0.0240 - categorical_accuracy: 0.9970
# Epoch 17: val_loss improved from 0.09032 to 0.06723, saving model to model_retrain_mobilenet_gru_64_2023-11-0616_51_17.626802/model-00017-0.02400-0.99698-0.06723-0.97000.h5
# 67/67 [==============================] - 143s 2s/step - loss: 0.0240 - categorical_accuracy: 0.9970 - val_loss: 0.0672 - val_categorical_accuracy: 0.9700 - lr: 1.0000e-04
# Epoch 18/20
# 67/67 [==============================] - ETA: 0s - loss: 0.0248 - categorical_accuracy: 0.9955
# Epoch 18: val_loss improved from 0.06723 to 0.06092, saving model to model_retrain_mobilenet_gru_64_2023-11-0616_51_17.626802/model-00018-0.02475-0.99548-0.06092-0.98000.h5
# 67/67 [==============================] - 143s 2s/step - loss: 0.0248 - categorical_accuracy: 0.9955 - val_loss: 0.0609 - val_categorical_accuracy: 0.9800 - lr: 1.0000e-04
# Epoch 19/20
# 67/67 [==============================] - ETA: 0s - loss: 0.0233 - categorical_accuracy: 0.9955
# Epoch 19: val_loss did not improve from 0.06092
# 67/67 [==============================] - 144s 2s/step - loss: 0.0233 - categorical_accuracy: 0.9955 - val_loss: 0.1399 - val_categorical_accuracy: 0.9600 - lr: 1.0000e-04
# Epoch 20/20
# 67/67 [==============================] - ETA: 0s - loss: 0.0402 - categorical_accuracy: 0.9894
# Epoch 20: val_loss did not improve from 0.06092
# 67/67 [==============================] - 143s 2s/step - loss: 0.0402 - categorical_accuracy: 0.9894 - val_loss: 0.0718 - val_categorical_accuracy: 0.9800 - lr: 1.0000e-04

# %%
plot_loss_accuracy(history)
# Out:
# dict_keys(['loss', 'categorical_accuracy', 'val_loss', 'val_categorical_accuracy', 'lr'])
